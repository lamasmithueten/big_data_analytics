# %%
import os
import re
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_name = os.getenv("DB_NAME")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")

# %%
db_url = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(db_url)

# %%
query = "SELECT * FROM intel;"
df = pd.read_sql(query, engine)

# %%
def convert_quarter_to_date(quarter_str):
    quarter, year = quarter_str.split("'")
    year = int("20" + year)
    month = {"Q1": 1, "Q2": 4, "Q3": 7, "Q4": 10}[quarter]
    return pd.Timestamp(year=year, month=month, day=1)

# %%
number_words = {
    "erste": 1, "zweite": 2, "dritte": 3, "vierte": 4, "fünfte": 5,
    "sechste": 6, "siebte": 7, "achte": 8, "neunte": 9, "zehnte": 10
}

def extract_generation(gen_text):
    match_numeric = re.search(r'(\d+)(?:\.|th)?\s?Gen', gen_text, re.IGNORECASE)
    if match_numeric:
        return int(match_numeric.group(1))
    for word, num in number_words.items():
        if word in gen_text.lower():
            return num
    return None

# %%
print(df)
# Out:
#                                      produktsortiment prozessornummer  \
# 0       Intel® Core™ i7 Prozessoren der 8. Generation        i7-8700K
# 1       Intel® Core™ i7 Prozessoren der 8. Generation         i7-8700
# 2       Intel® Core™ i7 Prozessoren der 8. Generation        i7-8700T
# 3      Intel® Core™ i7 Prozessoren der 12. Generation        i7-12700
# 4      Intel® Core™ i7 Prozessoren der 12. Generation       i7-12700F
# 5      Intel® Core™ i7 Prozessoren der 12. Generation       i7-12700K
# 6      Intel® Core™ i7 Prozessoren der 12. Generation      i7-12700KF
# 7      Intel® Core™ i7 Prozessoren der 12. Generation       i7-12700T
# 8       Intel® Core™ i7 Prozessoren der 8. Generation         i7-8700
# 9       Intel® Core™ i7 Prozessoren der 8. Generation        i7-8086K
# 10      Intel® Core™ i7 Prozessoren der 9. Generation        i7-9700K
# 11      Intel® Core™ i7 Prozessoren der 9. Generation       i7-9700KF
# 12      Intel® Core™ i7 Prozessoren der 9. Generation        i7-9700T
# 13      Intel® Core™ i7 Prozessoren der 9. Generation         i7-9700
# 14      Intel® Core™ i7 Prozessoren der 9. Generation        i7-9700F
# 15     Intel® Core™ i7 Prozessoren der 10. Generation       i7-10700T
# 16     Intel® Core™ i7 Prozessoren der 10. Generation        i7-10700
# 17     Intel® Core™ i7 Prozessoren der 10. Generation       i7-10700F
# 18     Intel® Core™ i7 Prozessoren der 10. Generation      i7-10700KF
# 19     Intel® Core™ i7 Prozessoren der 10. Generation       i7-10700K
# 20     Intel® Core™ i7 Prozessoren der 11. Generation       i7-11700K
# 21     Intel® Core™ i7 Prozessoren der 11. Generation      i7-11700KF
# 22     Intel® Core™ i7 Prozessoren der 11. Generation       i7-11700T
# 23     Intel® Core™ i7 Prozessoren der 11. Generation        i7-11700
# 24     Intel® Core™ i7 Prozessoren der 11. Generation       i7-11700F
# 25     Intel® Core™ i7 Prozessoren der 13. Generation      i7-13700KF
# 26     Intel® Core™ i7 Prozessoren der 13. Generation        i7-13700
# 27     Intel® Core™ i7 Prozessoren der 13. Generation       i7-13700F
# 28     Intel® Core™ i7 Prozessoren der 13. Generation       i7-13700T
# 29     Intel® Core™ i7 Prozessoren der 13. Generation       i7-13700K
# 30              Intel® Core™ i7 Processors (14th gen)        i7-14700
# 31              Intel® Core™ i7 Processors (14th gen)       i7-14700K
# 32              Intel® Core™ i7 Processors (14th gen)      i7-14700KF
# 33              Intel® Core™ i7 Processors (14th gen)       i7-14700T
# 34              Intel® Core™ i7 Processors (14th gen)       i7-14700F
# 35  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4765T
# 36  Intel® Core™ i7 Prozessoren der vierten Genera...         i7-4770
# 37  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4770K
# 38  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4770S
# 39  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4770T
# 40  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4770R
# 41  Intel® Core™ i7 Prozessoren der vierten Genera...         i7-4771
# 42  Intel® Core™ i7 Prozessoren der vierten Genera...         i7-4790
# 43  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4790K
# 44  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4790S
# 45  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4790T
# 46  Intel® Core™ i7 Prozessoren der vierten Genera...        i7-4785T
# 47  Intel® Core™ i7 Prozessoren der fünften Genera...        i7-5775R
# 48  Intel® Core™ i7 Prozessoren der fünften Genera...        i7-5775C
# 49  Intel® Core™ i7 Prozessoren der sechsten Gener...        i7-6700K
# 50  Intel® Core™ i7 Prozessoren der sechsten Gener...         i7-6700
# 51  Intel® Core™ i7 Prozessoren der sechsten Gener...        i7-6700T
# 52  Intel® Core™ i7 Prozessoren der sechsten Gener...        i7-6785R
# 53  Intel® Core™ i7 Prozessoren der siebten Genera...        i7-7700T
# 54  Intel® Core™ i7 Prozessoren der siebten Genera...         i7-7700
# 55  Intel® Core™ i7 Prozessoren der siebten Genera...        i7-7700K
#
#     litographie_nm  anzahl_der_kerne  gesamte_threads  \
# 0             14.0                 6               12
# 1             14.0                 6               12
# 2             14.0                 6               12
# 3             10.0                12               20
# 4             10.0                12               20
# 5             10.0                12               20
# 6             10.0                12               20
# 7             10.0                12               20
# 8             14.0                 6               12
# 9             14.0                 6               12
# 10            14.0                 8                8
# 11            14.0                 8                8
# 12            14.0                 8                8
# 13            14.0                 8                8
# 14            14.0                 8                8
# 15            14.0                 8               16
# 16            14.0                 8               16
# 17            14.0                 8               16
# 18            14.0                 8               16
# 19            14.0                 8               16
# 20            14.0                 8               16
# 21            14.0                 8               16
# 22            14.0                 8               16
# 23            14.0                 8               16
# 24            14.0                 8               16
# 25            10.0                16               24
# 26            10.0                16               24
# 27            10.0                16               24
# 28            10.0                16               24
# 29            10.0                16               24
# 30            10.0                20               28
# 31            10.0                20               28
# 32            10.0                20               28
# 33            10.0                20               28
# 34            10.0                20               28
# 35            22.0                 4                8
# 36            22.0                 4                8
# 37            22.0                 4                8
# 38            22.0                 4                8
# 39            22.0                 4                8
# 40            22.0                 4                8
# 41            22.0                 4                8
# 42            22.0                 4                8
# 43            22.0                 4                8
# 44            22.0                 4                8
# 45            22.0                 4                8
# 46            22.0                 4                8
# 47            14.0                 4                8
# 48            14.0                 4                8
# 49            14.0                 4                8
# 50            14.0                 4                8
# 51            14.0                 4                8
# 52            14.0                 4                8
# 53            14.0                 4                8
# 54            14.0                 4                8
# 55            14.0                 4                8
#
#     max_turbo_taktfrequenz_GHz  \
# 0                          4.7
# 1                          4.6
# 2                          4.0
# 3                          4.9
# 4                          4.9
# 5                          5.0
# 6                          5.0
# 7                          4.7
# 8                          4.6
# 9                          5.0
# 10                         4.9
# 11                         4.9
# 12                         4.3
# 13                         4.7
# 14                         4.7
# 15                         4.5
# 16                         4.8
# 17                         4.8
# 18                         5.1
# 19                         5.1
# 20                         5.0
# 21                         5.0
# 22                         4.6
# 23                         4.9
# 24                         4.9
# 25                         5.4
# 26                         5.2
# 27                         5.2
# 28                         4.9
# 29                         5.4
# 30                         5.4
# 31                         5.6
# 32                         5.6
# 33                         5.2
# 34                         5.4
# 35                         3.0
# 36                         3.9
# 37                         3.9
# 38                         3.9
# 39                         3.7
# 40                         3.9
# 41                         3.9
# 42                         4.0
# 43                         4.4
# 44                         4.0
# 45                         3.9
# 46                         3.2
# 47                         3.8
# 48                         3.7
# 49                         4.2
# 50                         4.0
# 51                         3.6
# 52                         3.9
# 53                         3.8
# 54                         4.2
# 55                         4.5
#
#     intel_turbo_boost_technik_2_0_taktfrequenz_GHz  \
# 0                                              4.7
# 1                                              4.6
# 2                                              4.0
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              4.6
# 9                                              5.0
# 10                                             4.9
# 11                                             4.9
# 12                                             4.3
# 13                                             4.7
# 14                                             4.7
# 15                                             4.4
# 16                                             4.7
# 17                                             4.7
# 18                                             5.0
# 19                                             5.0
# 20                                             4.9
# 21                                             4.9
# 22                                             4.5
# 23                                             4.8
# 24                                             4.8
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# 30                                             NaN
# 31                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 35                                             3.0
# 36                                             3.9
# 37                                             3.9
# 38                                             3.9
# 39                                             3.7
# 40                                             3.9
# 41                                             3.9
# 42                                             4.0
# 43                                             4.4
# 44                                             4.0
# 45                                             3.9
# 46                                             3.2
# 47                                             3.8
# 48                                             3.7
# 49                                             4.2
# 50                                             4.0
# 51                                             3.6
# 52                                             3.9
# 53                                             3.8
# 54                                             4.2
# 55                                             4.5
#
#     grundtaktfrequenz_des_prozessors_GHz  cache_MB  bus_taktfrequenz_GT_per_s  \
# 0                                    3.7      12.0                        8.0
# 1                                    3.2      12.0                        8.0
# 2                                    2.4      12.0                        8.0
# 3                                    NaN      25.0                        NaN
# 4                                    NaN      25.0                        NaN
# 5                                    NaN      25.0                        NaN
# 6                                    NaN      25.0                        NaN
# 7                                    NaN      25.0                        NaN
# 8                                    3.2      12.0                        8.0
# 9                                    4.0      12.0                        8.0
# 10                                   3.6      12.0                        8.0
# 11                                   3.6      12.0                        8.0
# 12                                   2.0      12.0                        8.0
# 13                                   3.0      12.0                        8.0
# 14                                   3.0      12.0                        8.0
# 15                                   2.0      16.0                        8.0
# 16                                   2.9      16.0                        8.0
# 17                                   2.9      16.0                        8.0
# 18                                   3.8      16.0                        8.0
# 19                                   3.8      16.0                        8.0
# 20                                   3.6      16.0                        8.0
# 21                                   3.6      16.0                        8.0
# 22                                   1.4      16.0                        8.0
# 23                                   2.5      16.0                        8.0
# 24                                   2.5      16.0                        8.0
# 25                                   NaN      30.0                        NaN
# 26                                   NaN      30.0                        NaN
# 27                                   NaN      30.0                        NaN
# 28                                   NaN      30.0                        NaN
# 29                                   NaN      30.0                        NaN
# 30                                   NaN      33.0                        NaN
# 31                                   NaN      33.0                        NaN
# 32                                   NaN      33.0                        NaN
# 33                                   NaN      33.0                        NaN
# 34                                   NaN      33.0                        NaN
# 35                                   2.0       8.0                        5.0
# 36                                   3.4       8.0                        5.0
# 37                                   3.5       8.0                        5.0
# 38                                   3.1       8.0                        5.0
# 39                                   2.5       8.0                        5.0
# 40                                   3.2       6.0                        5.0
# 41                                   3.5       8.0                        5.0
# 42                                   3.6       8.0                        5.0
# 43                                   4.0       8.0                        5.0
# 44                                   3.2       8.0                        5.0
# 45                                   2.7       8.0                        5.0
# 46                                   2.2       8.0                        5.0
# 47                                   3.3       6.0                        5.0
# 48                                   3.3       6.0                        5.0
# 49                                   4.0       8.0                        8.0
# 50                                   3.4       8.0                        8.0
# 51                                   2.8       8.0                        8.0
# 52                                   3.3       8.0                        8.0
# 53                                   2.9       8.0                        8.0
# 54                                   3.6       8.0                        8.0
# 55                                   4.2       8.0                        8.0
#
#     ...  expected_discontinuance  grundtaktfrequenz_der_grafik_MHz  \
# 0   ...                                                      350.0
# 1   ...                                                      350.0
# 2   ...                                                      350.0
# 3   ...                                                      300.0
# 4   ...                                                        NaN
# 5   ...                                                      300.0
# 6   ...                                                        NaN
# 7   ...                                                      300.0
# 8   ...                                                      350.0
# 9   ...                                                      350.0
# 10  ...                                                      350.0
# 11  ...                                                        NaN
# 12  ...                                                      350.0
# 13  ...                                                      350.0
# 14  ...                                                        NaN
# 15  ...                                                      350.0
# 16  ...                                                      350.0
# 17  ...                                                        NaN
# 18  ...                                                        NaN
# 19  ...                                                      350.0
# 20  ...                                                      350.0
# 21  ...                                                        NaN
# 22  ...                                                      350.0
# 23  ...                                                      350.0
# 24  ...                                                        NaN
# 25  ...                                                        NaN
# 26  ...                                                      300.0
# 27  ...                                                        NaN
# 28  ...                                                      300.0
# 29  ...                                                      300.0
# 30  ...                                                      300.0
# 31  ...                                                      300.0
# 32  ...                                                        NaN
# 33  ...                                                      300.0
# 34  ...                                                        NaN
# 35  ...               07/14/2017                             350.0
# 36  ...               07/14/2017                             350.0
# 37  ...                                                      350.0
# 38  ...                                                      350.0
# 39  ...               07/14/2017                             350.0
# 40  ...                                                      200.0
# 41  ...               07/14/2017                             350.0
# 42  ...               07/14/2017                             350.0
# 43  ...               07/14/2017                             350.0
# 44  ...                                                      350.0
# 45  ...               07/14/2017                             350.0
# 46  ...               07/14/2017                             350.0
# 47  ...                                                      300.0
# 48  ...                                                      300.0
# 49  ...                                                      350.0
# 50  ...                                                      350.0
# 51  ...                                                      350.0
# 52  ...                                                      350.0
# 53  ...                                                      350.0
# 54  ...                                                      350.0
# 55  ...                                                      350.0
#
#     max_dynamische_grafikfrequenz_GHz  max_videospeicher_der_grafik_GB  \
# 0                                1.20                             64.0
# 1                                1.20                             64.0
# 2                                1.20                             64.0
# 3                                1.50                              NaN
# 4                                 NaN                              NaN
# 5                                1.50                              NaN
# 6                                 NaN                              NaN
# 7                                1.50                              NaN
# 8                                1.20                             64.0
# 9                                1.20                             64.0
# 10                               1.20                             64.0
# 11                                NaN                              NaN
# 12                               1.20                             64.0
# 13                               1.20                             64.0
# 14                                NaN                              NaN
# 15                               1.20                             64.0
# 16                               1.20                             64.0
# 17                                NaN                              NaN
# 18                                NaN                              NaN
# 19                               1.20                             64.0
# 20                               1.30                             64.0
# 21                                NaN                              NaN
# 22                               1.30                             64.0
# 23                               1.30                             64.0
# 24                                NaN                              NaN
# 25                                NaN                              NaN
# 26                               1.60                              NaN
# 27                                NaN                              NaN
# 28                               1.60                              NaN
# 29                               1.60                              NaN
# 30                               1.60                              NaN
# 31                               1.60                              NaN
# 32                                NaN                              NaN
# 33                               1.60                              NaN
# 34                                NaN                              NaN
# 35                               1.20                              2.0
# 36                               1.20                              2.0
# 37                               1.25                              2.0
# 38                               1.20                              2.0
# 39                               1.20                              2.0
# 40                               1.30                              2.0
# 41                               1.20                              2.0
# 42                               1.20                              2.0
# 43                               1.25                              2.0
# 44                               1.20                              2.0
# 45                               1.20                              2.0
# 46                               1.20                              2.0
# 47                               1.15                             32.0
# 48                               1.15                             32.0
# 49                               1.15                             64.0
# 50                               1.15                             64.0
# 51                               1.10                             64.0
# 52                               1.15                             64.0
# 53                               1.15                             64.0
# 54                               1.15                             64.0
# 55                               1.15                             64.0
#
#     x4k_unterstutzung_at  max_auflosung_hdmi    max_auflosung_dp  \
# 0                   60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 1                   60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 2                   60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 3                    NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 4                    NaN
# 5                    NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 6                    NaN
# 7                    NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 8                   60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 9                   60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 10                  60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 11                   NaN
# 12                  60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 13                  60.0    4096 x 2304@24Hz    4096 x 2304@60Hz
# 14                   NaN
# 15                  60.0    4096 x 2160@30Hz    4096 x 2304@60Hz
# 16                  60.0    4096 x 2160@30Hz    4096 x 2304@60Hz
# 17                   NaN
# 18                   NaN
# 19                  60.0    4096 x 2160@30Hz    4096 x 2304@60Hz
# 20                  60.0      4096x2160@60Hz   5120 x 3200 @60Hz
# 21                   NaN
# 22                  60.0      4096x2160@60Hz   5120 x 3200 @60Hz
# 23                  60.0      4096x2160@60Hz   5120 x 3200 @60Hz
# 24                   NaN
# 25                   NaN
# 26                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 27                   NaN
# 28                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 29                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 30                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 31                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 32                   NaN
# 33                   NaN  4096 x 2160 @ 60Hz  7680 x 4320 @ 60Hz
# 34                   NaN
# 35                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 36                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 37                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 38                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 39                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 40                   NaN      3840x2160@30Hz      3840x2160@60Hz
# 41                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 42                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 43                   NaN      3840x2160@24Hz      3840x2160@60Hz
# 44                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 45                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 46                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 47                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 48                   NaN      4096x2304@24Hz      3840x2160@60Hz
# 49                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 50                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 51                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 52                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 53                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 54                  60.0      4096x2304@24Hz      4096x2304@60Hz
# 55                  60.0      4096x2304@24Hz      4096x2304@60Hz
#
#     max_auflosung_e_dp_integrierter_flachbildschirm  \
# 0                                  4096 x 2304@60Hz
# 1                                  4096 x 2304@60Hz
# 2                                  4096 x 2304@60Hz
# 3                               5120 x 3200 @ 120Hz
# 4
# 5                               5120 x 3200 @ 120Hz
# 6
# 7                               5120 x 3200 @ 120Hz
# 8                                  4096 x 2304@60Hz
# 9                                  4096 x 2304@60Hz
# 10                                 4096 x 2304@60Hz
# 11
# 12                                 4096 x 2304@60Hz
# 13                                 4096 x 2304@60Hz
# 14
# 15                                 4096 x 2304@60Hz
# 16                                 4096 x 2304@60Hz
# 17
# 18
# 19                                 4096 x 2304@60Hz
# 20                                5120 x 3200 @60Hz
# 21
# 22                                5120 x 3200 @60Hz
# 23                                5120 x 3200 @60Hz
# 24
# 25
# 26                              5120 x 3200 @ 120Hz
# 27
# 28                              5120 x 3200 @ 120Hz
# 29                              5120 x 3200 @ 120Hz
# 30                              5120 x 3200 @ 120Hz
# 31                              5120 x 3200 @ 120Hz
# 32
# 33                              5120 x 3200 @ 120Hz
# 34
# 35                                   3840x2160@60Hz
# 36                                   3840x2160@60Hz
# 37                                   3840x2160@60Hz
# 38                                   3840x2160@60Hz
# 39                                   3840x2160@60Hz
# 40
# 41                                   3840x2160@60Hz
# 42                                   3840x2160@60Hz
# 43                                   3840x2160@60Hz
# 44                                   3840x2160@60Hz
# 45                                   3840x2160@60Hz
# 46                                   3840x2160@60Hz
# 47                                   3840x2160@60Hz
# 48                                   3840x2160@60Hz
# 49                                   4096x2304@60Hz
# 50                                   4096x2304@60Hz
# 51                                   4096x2304@60Hz
# 52                                   4096x2304@60Hz
# 53                                   4096x2304@60Hz
# 54                                   4096x2304@60Hz
# 55                                   4096x2304@60Hz
#
#              pci_express_konfigurationen  thermische_spezifikation_des_kuhlers
# 0           Up to 1x16 |  2x8 |  1x8+2x4                      PCG 2015D (130W)
# 1           Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 2           Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015A (35W)
# 3                  Up to 1x16+4 |  2x8+4                             PCG 2020C
# 4                  Up to 1x16+4 |  2x8+4                             PCG 2020C
# 5                  Up to 1x16+4 |  2x8+4                             PCG 2020A
# 6                  Up to 1x16+4 |  2x8+4                             PCG 2020A
# 7                  Up to 1x16+4 |  2x8+4                             PCG 2020D
# 8           Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 9           Up to 1x16 |  2x8 |  1x8+2x4                      PCG 2015D (130W)
# 10          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015D
# 11          Up to 1x16 |  2x8 |  1x8+2x4                      PCG 2015D (130W)
# 12          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015A (35W)
# 13          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 14          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 15          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015B
# 16          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015C
# 17          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015C
# 18          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015D
# 19          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2015D
# 20  Up to 1x16+1x4 |  2x8+1x4 |  1x8+3x4                             PCG 2019A
# 21  Up to 1x16+1x4 |  2x8+1x4 |  1x8+3x4                             PCG 2019A
# 22  Up to 1x16+1x4 |  2x8+1x4 |  1x8+3x4                             PCG 2019D
# 23  Up to 1x16+1x4 |  2x8+1x4 |  1x8+3x4                             PCG 2019C
# 24  Up to 1x16+1x4 |  2x8+1x4 |  1x8+3x4                             PCG 2019C
# 25                 Up to 1x16+4 |  2x8+4                             PCG 2020A
# 26                 Up to 1x16+4 |  2x8+4                             PCG 2020C
# 27                 Up to 1x16+4 |  2x8+4                             PCG 2020C
# 28                 Up to 1x16+4 |  2x8+4                             PCG 2020D
# 29                 Up to 1x16+4 |  2x8+4                             PCG 2020A
# 30                 Up to 1x16+4 |  2x8+4                             PCG 2020C
# 31                 Up to 1x16+4 |  2x8+4                             PCG 2020A
# 32                 Up to 1x16+4 |  2x8+4                             PCG 2020A
# 33                 Up to 1x16+4 |  2x8+4                             PCG 2020D
# 34                 Up to 1x16+4 |  2x8+4                             PCG 2020C
# 35          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013A
# 36          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013D
# 37          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013D
# 38          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013C
# 39          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013B
# 40          Up to 1x16 |  2x8 |  1x8/2x4
# 41          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013D
# 42          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013D
# 43          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013D
# 44          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013C
# 45          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013B
# 46          Up to 1x16 |  2x8 |  1x8+2x4                             PCG 2013A
# 47          Up to 1x16 |  2x8 |  1x8+2x4                             PCA 2013D
# 48          Up to 1x16 |  2x8 |  1x8+2x4                             PCA 2013D
# 49          Up to 1x16 |  2x8 |  1x8+2x4                      PCG 2015D (130W)
# 50          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 51          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015A (35W)
# 52                  1x16 | 2x8 | 1x8+2x4                       PCG 2015C (65W)
# 53          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015A (35W)
# 54          Up to 1x16 |  2x8 |  1x8+2x4                       PCG 2015C (65W)
# 55          Up to 1x16 |  2x8 |  1x8+2x4                      PCG 2015D (130W)
#
# [56 rows x 32 columns]

# %%
print(df.columns)
# Out:
# Index(['produktsortiment', 'prozessornummer', 'litographie_nm',
#        'anzahl_der_kerne', 'gesamte_threads', 'max_turbo_taktfrequenz_GHz',
#        'intel_turbo_boost_technik_2_0_taktfrequenz_GHz',
#        'grundtaktfrequenz_des_prozessors_GHz', 'cache_MB',
#        'bus_taktfrequenz_GT_per_s', 'verlustleistung_tdp_W',
#        'x_of_performance_cores', 'x_of_efficiency_cores',
#        'intel_turbo_boost_max_technology_3_0_frequency_GHz',
#        'single_p_core_turbo_frequency_GHz',
#        'single_e_core_turbo_frequency_GHz', 'p_core_base_frequency',
#        'e_core_base_frequency_GHz', 'total_l2_cache_MB',
#        'processor_base_power_W', 'maximum_turbo_power_W', 'einfuhrungsdatum',
#        'expected_discontinuance', 'grundtaktfrequenz_der_grafik_MHz',
#        'max_dynamische_grafikfrequenz_GHz', 'max_videospeicher_der_grafik_GB',
#        'x4k_unterstutzung_at', 'max_auflosung_hdmi', 'max_auflosung_dp',
#        'max_auflosung_e_dp_integrierter_flachbildschirm',
#        'pci_express_konfigurationen', 'thermische_spezifikation_des_kuhlers'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sn.histplot (df['grundtaktfrequenz_des_prozessors_GHz'], bins=50, kde=True)
plt.title("Verteilung der Prozessor-Taktfrequenzen", fontsize=16)
plt.xlabel("Taktfrequenz (GHz)", fontsize=12)
plt.ylabel("Anzahl", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sn.countplot(data=df, x='litographie_nm', order=sorted(df['litographie_nm'], reverse=True))
plt.title("Anzahl der Prozessoren pro Fertigungsgröße", fontsize=16)
plt.xlabel("Litographie (nm)", fontsize=12)
plt.ylabel("Anzahl", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sn.scatterplot(data=df, x='grundtaktfrequenz_des_prozessors_GHz', y='max_turbo_taktfrequenz_GHz')
plt.title("Grundtakt vs. Turbotakt", fontsize=16)
plt.xlabel("Grundtaktfrequenz (GHz)", fontsize=12)
plt.ylabel("Turbotakt (GHz)", fontsize=12)
plt.show()

# %%
df['einfuhrungsdatum'] = df['einfuhrungsdatum'].apply(convert_quarter_to_date)

df['jahr'] = df['einfuhrungsdatum'].dt.year
performance_by_year = df.groupby('jahr')['grundtaktfrequenz_des_prozessors_GHz'].mean().reset_index()

plt.figure(figsize=(10, 6))
sn.lineplot(data=performance_by_year, x='jahr', y='grundtaktfrequenz_des_prozessors_GHz')
plt.title("Leistungsentwicklung über die Generationen", fontsize=16)
plt.xlabel("Einführungsjahr", fontsize=12)
plt.ylabel("Durchschnittliche Grundtaktfrequenz (GHz)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['generation'] = df['produktsortiment'].apply(extract_generation)

avg_clock_per_gen = df.groupby('generation')['grundtaktfrequenz_des_prozessors_GHz'].mean().reset_index()

max_gen = int(avg_clock_per_gen['generation'].max()) if not avg_clock_per_gen.empty else 0
min_gen = int(avg_clock_per_gen['generation'].min()) if not avg_clock_per_gen.empty else 0
all_generations = pd.DataFrame({'generation': range(min_gen, max_gen + 1)})

plt.figure(figsize=(10, 6))
sn.barplot(data=avg_clock_per_gen, x='generation', y='grundtaktfrequenz_des_prozessors_GHz')
plt.title("Durchschnittliche Taktfrequenz pro Generation", fontsize=16)
plt.xlabel("Generation", fontsize=12)
plt.ylabel("Taktfrequenz (GHz)", fontsize=12)

for i, row in avg_clock_per_gen.iterrows():
    if np.isnan(row['grundtaktfrequenz_des_prozessors_GHz']):
        plt.text(i, 0, 'N/A', ha='center', va='bottom', fontsize=9)

plt.show()
